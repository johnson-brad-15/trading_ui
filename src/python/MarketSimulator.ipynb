# %%
import threading
from MarketMaker import MarketMaker
from OrderBook import OrderBook
import websockets
import asyncio
import traceback
import sys
import json
from DataEvent import DataEvent, AsyncDataEvent
from Order import OrderStatus
import datetime as dt
import yfinance as yf

# %%
next_client_id = 0
id_lock = threading.Lock()
def getNextClientId():
    global next_client_id, id_lock
    id_lock.acquire()
    i = next_client_id
    next_client_id += 1
    id_lock.release()
    return i

# %%
class WebSocketSender:
    def __init__(self, ws):
        self.ws = ws
        self.ws_send = ws.send
        print(f'Created new WebSocketSender to {self.ws.remote_address}')

    async def send(self, msg):
        try:
            # print(f'{dt.datetime.now().timestamp()}:: Sending: {msg} on {self.ws.remote_address}')
            await self.ws_send(msg);
        except Exception as ex:
            print(ex)
            traceback.print_exc(file=sys.stdout)
        

class WebSocketHandler:
    def __init__(self, ob, mms):
        self.ob = ob
        self.mms = mms
        self.wsByClientId = {}
        self.wsSenders = []
        self.msgLock = asyncio.Lock()
        self.msgq = asyncio.Queue()
        self.ackEvent = AsyncDataEvent()
        asyncio.create_task(self.wait_ack(self.ackEvent))

    async def wait_ack(self, e):
        while True:
            print("MS:Awaiting acks")
            await e.waitRun(self.handle_ack)
            e.clear()

    async def handle_ack(self, ack):
        print(f"MS:New ack: {ack.status} {ack.order.id} {ack.order.clientId} {self.wsByClientId}")
        try:
            if ack.order.id < 0: # Manual MM
                if ack.order.clientId in self.wsByClientId:
                    if ack.status == OrderStatus.NEW:
                        ack_ = json.dumps({35:8,
                                             56:ack.order.clientId,
                                             39:0, # New
                                             11:ack.order.id,
                                             54:(1 if ack.order.side == "Buy" else 2),
                                             38:ack.order.qty,
                                             44:ack.order.px,
                                             52:str(dt.datetime.now())
                                            })
                    elif ack.status == OrderStatus.CANCELLED:
                        ack_ = json.dumps({35:8,
                                             56:ack.order.clientId,
                                             39:4, # Cancelled
                                             11:ack.order.id,
                                             54:(1 if ack.order.side == "Buy" else 2),
                                             38:ack.order.qty,
                                             44:ack.order.px,
                                             52:str(dt.datetime.now())
                                            })
                    elif ack.status == OrderStatus.MODIFIED:
                        ack_ = json.dumps({35:8,
                                             56:ack.order.clientId,
                                             39:5, # Replaced
                                             11:ack.order.id,
                                             54:(1 if ack.order.side == "Buy" else 2),
                                             38:ack.order.qty,
                                             44:ack.order.px,
                                             52:str(dt.datetime.now())
                                            })
                    elif ack.status in [ OrderStatus.FULLY_FILLED, OrderStatus.PARTIALLY_FILLED ]:
                        print('MS: Fill Ack: ', ack.status)
                        ack_ = json.dumps({ 35:8,
                                         56:ack.order.clientId,
                                         39:(2 if ack.status == OrderStatus.FULLY_FILLED else 1),
                                         11:ack.order.id,
                                         54:(1 if ack.order.side == "Buy" else 2),
                                         38:ack.order.qty,
                                         44:ack.order.px,
                                         52:str(dt.datetime.now())
                                       })
                    # print(f"Sending {ack_} to self.wsByClientId[ack.order.clientId]")
                    await self.wsByClientId[ack.order.clientId].send(ack_)
        except Exception as ex:
            print(ex)
            traceback.print_exc(file=sys.stdout)

    async def ws_recv(self, ws):
        # print(f'{dt.datetime.now().timestamp()}:: Waiting for msg from {ws}')
        await_msg_task = None
        asyncio.create_task(self.handle_ws_msg(ws))
        await asyncio.sleep(0)
        await ws.send(json.dumps({35:'d',55:symbol,15:currency,969:tick_sz,44:opening_px}))
        while True:
            # print(f'{dt.datetime.now().timestamp()}:: Lock: {self.msgLock}')
            # await self.msgLock.acquire()
            # print(f'{dt.datetime.now().timestamp()}:: Acquired Lock. Waiting for msg')
            try:
                msg = await ws.recv()
            
            except (websockets.exceptions.ConnectionClosedError, websockets.exceptions.ConnectionClosedOK):
                print(f'{dt.datetime.now().timestamp()}:: recv failed for {ws.remote_address}')
                break
            print(f'{dt.datetime.now().timestamp()}:: Received msg from {ws.remote_address}: {msg}')
            # self.msgLock.release()
            # print(f'{dt.datetime.now().timestamp()}:: Released Lock.')
            await self.msgq.put(msg)
        print(f'{dt.datetime.now().timestamp()}:: Done waiting on {ws.remote_address}')
        await self.msgq.put(None)

    async def handle_ws_msg(self, ws):
        while True:
            print(f'{dt.datetime.now().timestamp()}:: Waiting for queued msg from {ws.remote_address}')
            msg = await self.msgq.get()
            print(f'{dt.datetime.now().timestamp()}:: Dequeued msg from {ws.remote_address}: {msg}')
            if msg is None:
                break
            try:
                msg = json.loads(msg)
                if msg['35'] == 'A':
                    print("Logon message")
                    if msg['49'] == -1:
                        try:
                            print("New Client")
                            clientId = getNextClientId()
                            self.wsByClientId[clientId] = ws
                            self.mms[clientId] = MarketMaker(ob, self.ob.symbol, clientId, ms_ack_event=self.ackEvent, px=opening_px, default_qty=10, width=4)
                            print(f'Created MM')
                            reply = {35:"A",55:symbol,56:clientId,44:self.mms[clientId].px}
                            # print(f"Replying with {reply}")
                            await ws.send(json.dumps(reply))
                            await self.mms[clientId].start()
                        except Exception as ex:
                            print(ex)
                            traceback.print_exc(file=sys.stdout)
                elif msg['35'] == 5:
                    print("Logout")
                elif msg['35'] == 'D':
                    try:
                        # print("MS New msg")
                        await self.mms[msg['49']].place_new_order('Buy' if msg['38'] > 0 else 'Sell', msg['44'], abs(msg['38']))
                    except Exception as ex:
                        print(ex)
                        traceback.print_exc(file=sys.stdout)
                elif msg['35'] == 'F':
                    try:
                        # print("MS Cancel msg")
                        order_id = msg['11']
                        await self.mms[msg['49']].cancel_order(msg['11'])
                    except Exception as ex:
                        print(ex)
                        traceback.print_exc(file=sys.stdout)
                elif msg['35'] == 'G':
                    try:
                        # print("MS Modify msg")
                        order_id = msg['11']
                        await self.mms[msg['49']].modify_order(msg['11'], msg['44'])
                    except Exception as ex:
                        print(ex)
                        traceback.print_exc(file=sys.stdout)
            except Excpetion as ex:
                print(ex)
                traceback.print_exc(file=sys.stdout)
        print(f'{dt.datetime.now().timestamp()}:: Done waiting to dequeue msg from {ws.remote_address}')
        
    async def handler(self, websocket, path):
        try:
            sender = WebSocketSender(websocket)
            self.wsSenders.append(sender)
            ws_send = websocket.send
            # print(websocket.send)
            websocket.send = sender.send
            # print(websocket.send)
            self.ob.websocket.append(websocket)
            print(f"{dt.datetime.now().timestamp()}:: Client connected from: {websocket.remote_address} : {len(self.ob.websocket)}")
            await self.ws_recv(websocket)
        except websockets.exceptions.ConnectionClosedError:
            print("Client disconnected abruptly")
        except Exception as e:
            print(f"An error occurred: {e}")
        finally:
            await websocket.close()
            self.ob.websocket.remove(websocket)
            print(f"Client connection closed: {websocket.remote_address}")

# %%
async def main_async(ob, mms):
    wsHandler = WebSocketHandler(ob, mms)
    await ob.start()
    for client_id, mm in mms.items():
        await mm.start()
    try:
        port = 8765
        async with websockets.serve(wsHandler.handler, "localhost", port):
            print(f"WebSocket server started on ws://localhost:{port}")
            await asyncio.Future()  # run forever
    except Exception as ex:
        print(ex)
        traceback.print_exc(file=sys.stdout)

symbol = 'META'
# ticker = symbol # this is craziness, but it doesn't work if I just use symbol
# opening_px = yf.download(ticker, start=dt.datetime.now().strftime('%Y-%m-%d'), auto_adjust=True)['Open'].iloc[0][0]
opening_px = 720.00
currency = 'USD'
tick_sz = 0.01

if __name__ == "__main__":
    book_event = asyncio.Event()
    ob = OrderBook(symbol)
    mms = {}
    client_id = getNextClientId()
    mms[client_id] = MarketMaker(ob, symbol, client_id, px=opening_px, default_qty=10, width=4)
    await(main_async(ob, mms))
# Out:
# MS:Awaiting acks
# Awaiting new orders
# Awaiting modifies
# Awaiting cancels
# Waiting to send book
# Waiting to send trades
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9713B430 [unset]>
# 1750110541.586985:: OB:Setting New Order AckEvent: <DataEvent.AsyncDataEvent object at 0x000001AB9713B430 [unset, waiters:1]>
# 1750110541.586985:: OB:Setting New Order AckEvent: <DataEvent.AsyncDataEvent object at 0x000001AB9713B430 [unset, waiters:1]>
# WebSocket server started on ws://localhost:8765
# Created new WebSocketSender to ('::1', 62286, 0, 0)
# 1750110546.6204:: Client connected from: ('::1', 62286, 0, 0) : 1
# 1750110546.6204:: Waiting for queued msg from ('::1', 62286, 0, 0)
# 1750110546.62841:: Received msg from ('::1', 62286, 0, 0): {"35":"A","49":-1}
# 1750110546.62841:: Dequeued msg from ('::1', 62286, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750110546.629713:: Waiting for queued msg from ('::1', 62286, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB8671DE20 [unset]>
# no close frame received or sent
# Traceback (most recent call last):
#   File "C:\Users\johns\AppData\Local\Temp\ipykernel_8828\454572607.py", line 10, in send
#     await self.ws_send(msg);
#   File "C:\Users\johns\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\websockets\legacy\protocol.py", line 640, in send
#     await self.write_frame(True, opcode, data)
#   File "C:\Users\johns\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\websockets\legacy\protocol.py", line 1199, in write_frame
#     await self.drain()
#   File "C:\Users\johns\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\websockets\legacy\protocol.py", line 1188, in drain
#     await self.ensure_open()
#   File "C:\Users\johns\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\websockets\legacy\protocol.py", line 929, in ensure_open
#     raise self.connection_closed_exc()
# websockets.exceptions.ConnectionClosedError: no close frame received or sent
# 1750110686.071639:: recv failed for ('::1', 62286, 0, 0)
# 1750110686.142439:: Done waiting on ('::1', 62286, 0, 0)
# Client connection closed: ('::1', 62286, 0, 0)
# 1750110686.188807:: Dequeued msg from ('::1', 62286, 0, 0): None
# 1750110686.188807:: Done waiting to dequeue msg from ('::1', 62286, 0, 0)
# Created new WebSocketSender to ('::1', 62825, 0, 0)
# 1750115797.223315:: Client connected from: ('::1', 62825, 0, 0) : 1
# 1750115797.223315:: Waiting for queued msg from ('::1', 62825, 0, 0)
# 1750115797.23356:: Received msg from ('::1', 62825, 0, 0): {"35":"A","49":-1}
# 1750115797.23356:: Dequeued msg from ('::1', 62825, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750115797.234867:: Waiting for queued msg from ('::1', 62825, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB866E9370 [unset]>
# 1750116518.322379:: recv failed for ('::1', 62825, 0, 0)
# 1750116518.322379:: Done waiting on ('::1', 62825, 0, 0)
# 1750116518.322379:: Dequeued msg from ('::1', 62825, 0, 0): None
# 1750116518.322379:: Done waiting to dequeue msg from ('::1', 62825, 0, 0)
# Client connection closed: ('::1', 62825, 0, 0)
# Created new WebSocketSender to ('::1', 63581, 0, 0)
# 1750116710.762983:: Client connected from: ('::1', 63581, 0, 0) : 1
# 1750116710.762983:: Waiting for queued msg from ('::1', 63581, 0, 0)
# 1750116710.770987:: Received msg from ('::1', 63581, 0, 0): {"35":"A","49":-1}
# 1750116710.770987:: Dequeued msg from ('::1', 63581, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750116710.771982:: Waiting for queued msg from ('::1', 63581, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB86718040 [unset]>
# Created new WebSocketSender to ('::1', 63618, 0, 0)
# 1750116751.212795:: Client connected from: ('::1', 63618, 0, 0) : 2
# 1750116751.213793:: Waiting for queued msg from ('::1', 63618, 0, 0)
# 1750116751.221805:: Received msg from ('::1', 63618, 0, 0): {"35":"A","49":-1}
# 1750116751.221805:: Dequeued msg from ('::1', 63581, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750116751.223793:: Waiting for queued msg from ('::1', 63581, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB970AFAC0 [unset]>
# Created new WebSocketSender to ('::1', 63619, 0, 0)
# 1750116751.275305:: Client connected from: ('::1', 63619, 0, 0) : 3
# 1750116751.276304:: Waiting for queued msg from ('::1', 63619, 0, 0)
# 1750116751.278303:: Received msg from ('::1', 63619, 0, 0): {"35":"A","49":-1}
# 1750116751.279302:: Dequeued msg from ('::1', 63618, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750116751.279302:: Waiting for queued msg from ('::1', 63618, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9714E340 [unset]>
# 1750116753.419723:: recv failed for ('::1', 63581, 0, 0)
# 1750116753.419723:: Done waiting on ('::1', 63581, 0, 0)
# 1750116753.421734:: Dequeued msg from ('::1', 63581, 0, 0): None
# 1750116753.421734:: Done waiting to dequeue msg from ('::1', 63581, 0, 0)
# 1750116753.423753:: recv failed for ('::1', 63618, 0, 0)
# 1750116753.423753:: Done waiting on ('::1', 63618, 0, 0)
# 1750116753.423753:: recv failed for ('::1', 63619, 0, 0)
# 1750116753.423753:: Done waiting on ('::1', 63619, 0, 0)
# Client connection closed: ('::1', 63581, 0, 0)
# 1750116753.423753:: Dequeued msg from ('::1', 63619, 0, 0): None
# 1750116753.423753:: Done waiting to dequeue msg from ('::1', 63619, 0, 0)
# 1750116753.423753:: Dequeued msg from ('::1', 63618, 0, 0): None
# 1750116753.423753:: Done waiting to dequeue msg from ('::1', 63618, 0, 0)
# Client connection closed: ('::1', 63618, 0, 0)
# Client connection closed: ('::1', 63619, 0, 0)
# Created new WebSocketSender to ('::1', 63623, 0, 0)
# 1750116753.871513:: Client connected from: ('::1', 63623, 0, 0) : 1
# 1750116753.871513:: Waiting for queued msg from ('::1', 63623, 0, 0)
# 1750116753.882181:: Received msg from ('::1', 63623, 0, 0): {"35":"A","49":-1}
# 1750116753.88317:: Dequeued msg from ('::1', 63623, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750116753.88317:: Waiting for queued msg from ('::1', 63623, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9714E250 [unset]>
# Created new WebSocketSender to ('::1', 63735, 0, 0)
# 1750116957.232441:: Client connected from: ('::1', 63735, 0, 0) : 2
# 1750116957.232441:: Waiting for queued msg from ('::1', 63735, 0, 0)
# 1750116957.23966:: Received msg from ('::1', 63735, 0, 0): {"35":"A","49":-1}
# 1750116957.23966:: Dequeued msg from ('::1', 63623, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750116957.23966:: Waiting for queued msg from ('::1', 63623, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9714E880 [unset]>
# Created new WebSocketSender to ('::1', 63760, 0, 0)
# 1750116992.232047:: Client connected from: ('::1', 63760, 0, 0) : 3
# 1750116992.232047:: Waiting for queued msg from ('::1', 63760, 0, 0)
# 1750116992.232047:: Received msg from ('::1', 63760, 0, 0): {"35":"A","49":-1}
# 1750116992.232047:: Dequeued msg from ('::1', 63735, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750116992.232047:: Waiting for queued msg from ('::1', 63735, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9714EF10 [unset]>
# Created new WebSocketSender to ('::1', 63771, 0, 0)
# 1750117006.231311:: Client connected from: ('::1', 63771, 0, 0) : 4
# 1750117006.231311:: Waiting for queued msg from ('::1', 63771, 0, 0)
# 1750117006.231311:: Received msg from ('::1', 63771, 0, 0): {"35":"A","49":-1}
# 1750117006.231311:: Dequeued msg from ('::1', 63623, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117006.231311:: Waiting for queued msg from ('::1', 63623, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9715B5E0 [unset]>
# 1750117010.202563:: recv failed for ('::1', 63623, 0, 0)
# 1750117010.202563:: Done waiting on ('::1', 63623, 0, 0)
# 1750117010.203563:: Dequeued msg from ('::1', 63760, 0, 0): None
# 1750117010.203563:: Done waiting to dequeue msg from ('::1', 63760, 0, 0)
# 1750117010.203563:: recv failed for ('::1', 63735, 0, 0)
# 1750117010.203563:: Done waiting on ('::1', 63735, 0, 0)
# 1750117010.204563:: Dequeued msg from ('::1', 63735, 0, 0): None
# 1750117010.204563:: Done waiting to dequeue msg from ('::1', 63735, 0, 0)
# 1750117010.204563:: recv failed for ('::1', 63771, 0, 0)
# 1750117010.204563:: Done waiting on ('::1', 63771, 0, 0)
# 1750117010.204563:: recv failed for ('::1', 63760, 0, 0)
# 1750117010.204563:: Done waiting on ('::1', 63760, 0, 0)
# Client connection closed: ('::1', 63623, 0, 0)
# 1750117010.204563:: Dequeued msg from ('::1', 63771, 0, 0): None
# 1750117010.204563:: Done waiting to dequeue msg from ('::1', 63771, 0, 0)
# 1750117010.204563:: Dequeued msg from ('::1', 63623, 0, 0): None
# 1750117010.204563:: Done waiting to dequeue msg from ('::1', 63623, 0, 0)
# Client connection closed: ('::1', 63735, 0, 0)
# Client connection closed: ('::1', 63771, 0, 0)
# Client connection closed: ('::1', 63760, 0, 0)
# Created new WebSocketSender to ('::1', 63776, 0, 0)
# 1750117010.639186:: Client connected from: ('::1', 63776, 0, 0) : 1
# 1750117010.639186:: Waiting for queued msg from ('::1', 63776, 0, 0)
# 1750117010.649166:: Received msg from ('::1', 63776, 0, 0): {"35":"A","49":-1}
# 1750117010.649166:: Dequeued msg from ('::1', 63776, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117010.649166:: Waiting for queued msg from ('::1', 63776, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9714ED00 [unset]>
# Created new WebSocketSender to ('::1', 63835, 0, 0)
# 1750117076.240247:: Client connected from: ('::1', 63835, 0, 0) : 2
# 1750117076.240247:: Waiting for queued msg from ('::1', 63835, 0, 0)
# 1750117076.242647:: Received msg from ('::1', 63835, 0, 0): {"35":"A","49":-1}
# 1750117076.242952:: Dequeued msg from ('::1', 63776, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117076.243973:: Waiting for queued msg from ('::1', 63776, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9715B8B0 [unset]>
# Created new WebSocketSender to ('::1', 63840, 0, 0)
# 1750117081.220564:: Client connected from: ('::1', 63840, 0, 0) : 3
# 1750117081.220564:: Waiting for queued msg from ('::1', 63840, 0, 0)
# 1750117081.220564:: Received msg from ('::1', 63840, 0, 0): {"35":"A","49":-1}
# 1750117081.220564:: Dequeued msg from ('::1', 63835, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117081.220564:: Waiting for queued msg from ('::1', 63835, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9715BE50 [unset]>
# 1750117085.748645:: recv failed for ('::1', 63776, 0, 0)
# 1750117085.748645:: Done waiting on ('::1', 63776, 0, 0)
# 1750117085.74964:: Dequeued msg from ('::1', 63776, 0, 0): None
# 1750117085.74964:: Done waiting to dequeue msg from ('::1', 63776, 0, 0)
# 1750117085.74964:: recv failed for ('::1', 63835, 0, 0)
# 1750117085.750641:: Done waiting on ('::1', 63835, 0, 0)
# 1750117085.750641:: recv failed for ('::1', 63840, 0, 0)
# 1750117085.750641:: Done waiting on ('::1', 63840, 0, 0)
# Client connection closed: ('::1', 63776, 0, 0)
# 1750117085.750641:: Dequeued msg from ('::1', 63840, 0, 0): None
# 1750117085.750641:: Done waiting to dequeue msg from ('::1', 63840, 0, 0)
# 1750117085.750641:: Dequeued msg from ('::1', 63835, 0, 0): None
# 1750117085.750641:: Done waiting to dequeue msg from ('::1', 63835, 0, 0)
# Client connection closed: ('::1', 63835, 0, 0)
# Client connection closed: ('::1', 63840, 0, 0)
# Created new WebSocketSender to ('::1', 63848, 0, 0)
# 1750117086.240163:: Client connected from: ('::1', 63848, 0, 0) : 1
# 1750117086.240163:: Waiting for queued msg from ('::1', 63848, 0, 0)
# 1750117086.243162:: Received msg from ('::1', 63848, 0, 0): {"35":"A","49":-1}
# 1750117086.244165:: Dequeued msg from ('::1', 63848, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117086.244165:: Waiting for queued msg from ('::1', 63848, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9715B1C0 [unset]>
# Created new WebSocketSender to ('::1', 63865, 0, 0)
# 1750117098.447598:: Client connected from: ('::1', 63865, 0, 0) : 2
# 1750117098.448592:: Waiting for queued msg from ('::1', 63865, 0, 0)
# 1750117098.449598:: Received msg from ('::1', 63865, 0, 0): {"35":"A","49":-1}
# 1750117098.449598:: Dequeued msg from ('::1', 63848, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117098.450599:: Waiting for queued msg from ('::1', 63848, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9716F340 [unset]>
# 1750117099.799626:: recv failed for ('::1', 63848, 0, 0)
# 1750117099.799626:: Done waiting on ('::1', 63848, 0, 0)
# 1750117099.799626:: Dequeued msg from ('::1', 63865, 0, 0): None
# 1750117099.799626:: Done waiting to dequeue msg from ('::1', 63865, 0, 0)
# 1750117099.799626:: recv failed for ('::1', 63865, 0, 0)
# 1750117099.799626:: Done waiting on ('::1', 63865, 0, 0)
# Client connection closed: ('::1', 63848, 0, 0)
# 1750117099.799626:: Dequeued msg from ('::1', 63848, 0, 0): None
# 1750117099.799626:: Done waiting to dequeue msg from ('::1', 63848, 0, 0)
# Client connection closed: ('::1', 63865, 0, 0)
# Created new WebSocketSender to ('::1', 63868, 0, 0)
# 1750117100.289436:: Client connected from: ('::1', 63868, 0, 0) : 1
# 1750117100.289436:: Waiting for queued msg from ('::1', 63868, 0, 0)
# 1750117100.299447:: Received msg from ('::1', 63868, 0, 0): {"35":"A","49":-1}
# 1750117100.299447:: Dequeued msg from ('::1', 63868, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117100.300445:: Waiting for queued msg from ('::1', 63868, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9716F190 [unset]>
# Created new WebSocketSender to ('::1', 63913, 0, 0)
# 1750117156.233526:: Client connected from: ('::1', 63913, 0, 0) : 2
# 1750117156.233526:: Waiting for queued msg from ('::1', 63913, 0, 0)
# 1750117156.233526:: Received msg from ('::1', 63913, 0, 0): {"35":"A","49":-1}
# 1750117156.233526:: Dequeued msg from ('::1', 63868, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117156.233526:: Waiting for queued msg from ('::1', 63868, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9716FAC0 [unset]>
# 1750117169.411715:: recv failed for ('::1', 63868, 0, 0)
# 1750117169.411715:: Done waiting on ('::1', 63868, 0, 0)
# 1750117169.412713:: Dequeued msg from ('::1', 63913, 0, 0): None
# 1750117169.412713:: Done waiting to dequeue msg from ('::1', 63913, 0, 0)
# 1750117169.412713:: recv failed for ('::1', 63913, 0, 0)
# 1750117169.412713:: Done waiting on ('::1', 63913, 0, 0)
# 1750117169.412713:: Dequeued msg from ('::1', 63868, 0, 0): None
# 1750117169.412713:: Done waiting to dequeue msg from ('::1', 63868, 0, 0)
# Client connection closed: ('::1', 63868, 0, 0)
# Client connection closed: ('::1', 63913, 0, 0)
# Created new WebSocketSender to ('::1', 63929, 0, 0)
# 1750117169.868102:: Client connected from: ('::1', 63929, 0, 0) : 1
# 1750117169.869139:: Waiting for queued msg from ('::1', 63929, 0, 0)
# 1750117169.872103:: Received msg from ('::1', 63929, 0, 0): {"35":"A","49":-1}
# 1750117169.872103:: Dequeued msg from ('::1', 63929, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117169.873101:: Waiting for queued msg from ('::1', 63929, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9716FB20 [unset]>
# Created new WebSocketSender to ('::1', 63979, 0, 0)
# 1750117232.221828:: Client connected from: ('::1', 63979, 0, 0) : 2
# 1750117232.221828:: Waiting for queued msg from ('::1', 63979, 0, 0)
# 1750117232.221828:: Received msg from ('::1', 63979, 0, 0): {"35":"A","49":-1}
# 1750117232.221828:: Dequeued msg from ('::1', 63929, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117232.221828:: Waiting for queued msg from ('::1', 63929, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9717D220 [unset]>
# 1750117269.997702:: recv failed for ('::1', 63929, 0, 0)
# 1750117269.997702:: Done waiting on ('::1', 63929, 0, 0)
# 1750117269.997702:: Dequeued msg from ('::1', 63979, 0, 0): None
# 1750117269.997702:: Done waiting to dequeue msg from ('::1', 63979, 0, 0)
# 1750117269.997702:: recv failed for ('::1', 63979, 0, 0)
# 1750117269.997702:: Done waiting on ('::1', 63979, 0, 0)
# Client connection closed: ('::1', 63929, 0, 0)
# 1750117269.997702:: Dequeued msg from ('::1', 63929, 0, 0): None
# 1750117269.997702:: Done waiting to dequeue msg from ('::1', 63929, 0, 0)
# Client connection closed: ('::1', 63979, 0, 0)
# Created new WebSocketSender to ('::1', 64000, 0, 0)
# 1750117270.466771:: Client connected from: ('::1', 64000, 0, 0) : 1
# 1750117270.466771:: Waiting for queued msg from ('::1', 64000, 0, 0)
# 1750117270.470839:: Received msg from ('::1', 64000, 0, 0): {"35":"A","49":-1}
# 1750117270.470839:: Dequeued msg from ('::1', 64000, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117270.472849:: Waiting for queued msg from ('::1', 64000, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9717D160 [unset]>
# 1750117286.050173:: recv failed for ('::1', 64000, 0, 0)
# 1750117286.051175:: Done waiting on ('::1', 64000, 0, 0)
# 1750117286.051175:: Dequeued msg from ('::1', 64000, 0, 0): None
# 1750117286.051175:: Done waiting to dequeue msg from ('::1', 64000, 0, 0)
# Client connection closed: ('::1', 64000, 0, 0)
# Created new WebSocketSender to ('::1', 64022, 0, 0)
# 1750117286.513489:: Client connected from: ('::1', 64022, 0, 0) : 1
# 1750117286.514485:: Waiting for queued msg from ('::1', 64022, 0, 0)
# 1750117286.526684:: Received msg from ('::1', 64022, 0, 0): {"35":"A","49":-1}
# 1750117286.526684:: Dequeued msg from ('::1', 64022, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117286.527683:: Waiting for queued msg from ('::1', 64022, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9717D6D0 [unset]>
# Created new WebSocketSender to ('::1', 64038, 0, 0)
# 1750117311.212096:: Client connected from: ('::1', 64038, 0, 0) : 2
# 1750117311.212096:: Waiting for queued msg from ('::1', 64038, 0, 0)
# 1750117311.228058:: Received msg from ('::1', 64038, 0, 0): {"35":"A","49":-1}
# 1750117311.228058:: Dequeued msg from ('::1', 64022, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117311.228058:: Waiting for queued msg from ('::1', 64022, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9717DD00 [unset]>
# Created new WebSocketSender to ('::1', 64041, 0, 0)
# 1750117316.231726:: Client connected from: ('::1', 64041, 0, 0) : 3
# 1750117316.231726:: Waiting for queued msg from ('::1', 64041, 0, 0)
# 1750117316.231726:: Received msg from ('::1', 64041, 0, 0): {"35":"A","49":-1}
# 1750117316.231726:: Dequeued msg from ('::1', 64038, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117316.231726:: Waiting for queued msg from ('::1', 64038, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9718B400 [unset]>
# 1750117320.754418:: recv failed for ('::1', 64022, 0, 0)
# 1750117320.754418:: Done waiting on ('::1', 64022, 0, 0)
# 1750117320.755409:: Dequeued msg from ('::1', 64022, 0, 0): None
# 1750117320.755409:: Done waiting to dequeue msg from ('::1', 64022, 0, 0)
# 1750117320.756416:: recv failed for ('::1', 64038, 0, 0)
# 1750117320.756416:: Done waiting on ('::1', 64038, 0, 0)
# Client connection closed: ('::1', 64022, 0, 0)
# 1750117320.756416:: Dequeued msg from ('::1', 64041, 0, 0): None
# 1750117320.756416:: Done waiting to dequeue msg from ('::1', 64041, 0, 0)
# 1750117320.756416:: recv failed for ('::1', 64041, 0, 0)
# 1750117320.756416:: Done waiting on ('::1', 64041, 0, 0)
# 1750117320.756416:: Dequeued msg from ('::1', 64038, 0, 0): None
# 1750117320.756416:: Done waiting to dequeue msg from ('::1', 64038, 0, 0)
# Client connection closed: ('::1', 64038, 0, 0)
# Client connection closed: ('::1', 64041, 0, 0)
# Created new WebSocketSender to ('::1', 64047, 0, 0)
# 1750117321.122355:: Client connected from: ('::1', 64047, 0, 0) : 1
# 1750117321.122355:: Waiting for queued msg from ('::1', 64047, 0, 0)
# 1750117321.128352:: Received msg from ('::1', 64047, 0, 0): {"35":"A","49":-1}
# 1750117321.128352:: Dequeued msg from ('::1', 64047, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117321.128352:: Waiting for queued msg from ('::1', 64047, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9718B190 [unset]>
# Created new WebSocketSender to ('::1', 64087, 0, 0)
# 1750117346.224676:: Client connected from: ('::1', 64087, 0, 0) : 2
# 1750117346.224676:: Waiting for queued msg from ('::1', 64087, 0, 0)
# 1750117346.224676:: Received msg from ('::1', 64087, 0, 0): {"35":"A","49":-1}
# 1750117346.224676:: Dequeued msg from ('::1', 64047, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117346.224676:: Waiting for queued msg from ('::1', 64047, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9718B940 [unset]>
# Created new WebSocketSender to ('::1', 64248, 0, 0)
# 1750117537.237373:: Client connected from: ('::1', 64248, 0, 0) : 3
# 1750117537.237373:: Waiting for queued msg from ('::1', 64248, 0, 0)
# 1750117537.238374:: Received msg from ('::1', 64248, 0, 0): {"35":"A","49":-1}
# 1750117537.238374:: Dequeued msg from ('::1', 64087, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117537.239373:: Waiting for queued msg from ('::1', 64087, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9718BFD0 [unset]>
# 1750117563.460606:: recv failed for ('::1', 64047, 0, 0)
# 1750117563.460606:: Done waiting on ('::1', 64047, 0, 0)
# 1750117563.460606:: Dequeued msg from ('::1', 64047, 0, 0): None
# 1750117563.460606:: Done waiting to dequeue msg from ('::1', 64047, 0, 0)
# 1750117563.460606:: recv failed for ('::1', 64248, 0, 0)
# 1750117563.460606:: Done waiting on ('::1', 64248, 0, 0)
# 1750117563.465077:: recv failed for ('::1', 64087, 0, 0)
# 1750117563.465077:: Done waiting on ('::1', 64087, 0, 0)
# 1750117563.465077:: Dequeued msg from ('::1', 64248, 0, 0): None
# 1750117563.465077:: Done waiting to dequeue msg from ('::1', 64248, 0, 0)
# 1750117563.465077:: Dequeued msg from ('::1', 64087, 0, 0): None
# 1750117563.465077:: Done waiting to dequeue msg from ('::1', 64087, 0, 0)
# Client connection closed: ('::1', 64047, 0, 0)
# Client connection closed: ('::1', 64248, 0, 0)
# Client connection closed: ('::1', 64087, 0, 0)
# Created new WebSocketSender to ('::1', 64273, 0, 0)
# 1750117563.918099:: Client connected from: ('::1', 64273, 0, 0) : 1
# 1750117563.918099:: Waiting for queued msg from ('::1', 64273, 0, 0)
# 1750117563.978646:: Received msg from ('::1', 64273, 0, 0): {"35":"A","49":-1}
# 1750117563.979647:: Dequeued msg from ('::1', 64273, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117563.979647:: Waiting for queued msg from ('::1', 64273, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9717DE20 [unset]>
# 1750117592.158116:: recv failed for ('::1', 64273, 0, 0)
# 1750117592.159118:: Done waiting on ('::1', 64273, 0, 0)
# 1750117592.159118:: Dequeued msg from ('::1', 64273, 0, 0): None
# 1750117592.159118:: Done waiting to dequeue msg from ('::1', 64273, 0, 0)
# Client connection closed: ('::1', 64273, 0, 0)
# Created new WebSocketSender to ('::1', 64298, 0, 0)
# 1750117592.510057:: Client connected from: ('::1', 64298, 0, 0) : 1
# 1750117592.511064:: Waiting for queued msg from ('::1', 64298, 0, 0)
# 1750117592.521064:: Received msg from ('::1', 64298, 0, 0): {"35":"A","49":-1}
# 1750117592.522068:: Dequeued msg from ('::1', 64298, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117592.523064:: Waiting for queued msg from ('::1', 64298, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9719E250 [unset]>
# 1750117757.864585:: recv failed for ('::1', 64298, 0, 0)
# 1750117757.864585:: Done waiting on ('::1', 64298, 0, 0)
# 1750117757.864585:: Dequeued msg from ('::1', 64298, 0, 0): None
# 1750117757.864585:: Done waiting to dequeue msg from ('::1', 64298, 0, 0)
# Client connection closed: ('::1', 64298, 0, 0)
# Created new WebSocketSender to ('::1', 64430, 0, 0)
# 1750117758.366862:: Client connected from: ('::1', 64430, 0, 0) : 1
# 1750117758.366862:: Waiting for queued msg from ('::1', 64430, 0, 0)
# 1750117758.383125:: Received msg from ('::1', 64430, 0, 0): {"35":"A","49":-1}
# 1750117758.383125:: Dequeued msg from ('::1', 64430, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117758.384126:: Waiting for queued msg from ('::1', 64430, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9719E430 [unset]>
# 1750117850.333105:: recv failed for ('::1', 64430, 0, 0)
# 1750117850.334111:: Done waiting on ('::1', 64430, 0, 0)
# 1750117850.335101:: Dequeued msg from ('::1', 64430, 0, 0): None
# 1750117850.335101:: Done waiting to dequeue msg from ('::1', 64430, 0, 0)
# Client connection closed: ('::1', 64430, 0, 0)
# Created new WebSocketSender to ('::1', 64503, 0, 0)
# 1750117850.729299:: Client connected from: ('::1', 64503, 0, 0) : 1
# 1750117850.729299:: Waiting for queued msg from ('::1', 64503, 0, 0)
# 1750117850.736467:: Received msg from ('::1', 64503, 0, 0): {"35":"A","49":-1}
# 1750117850.737468:: Dequeued msg from ('::1', 64503, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750117850.737468:: Waiting for queued msg from ('::1', 64503, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9719E970 [unset]>
# Created new WebSocketSender to ('::1', 64616, 0, 0)
# 1750118004.23228:: Client connected from: ('::1', 64616, 0, 0) : 2
# 1750118004.23228:: Waiting for queued msg from ('::1', 64616, 0, 0)
# 1750118004.23228:: Received msg from ('::1', 64616, 0, 0): {"35":"A","49":-1}
# 1750118004.23228:: Dequeued msg from ('::1', 64503, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750118004.23228:: Waiting for queued msg from ('::1', 64503, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9719EFA0 [unset]>
# Created new WebSocketSender to ('::1', 64668, 0, 0)
# 1750118073.22552:: Client connected from: ('::1', 64668, 0, 0) : 3
# 1750118073.22552:: Waiting for queued msg from ('::1', 64668, 0, 0)
# 1750118073.22552:: Received msg from ('::1', 64668, 0, 0): {"35":"A","49":-1}
# 1750118073.22552:: Dequeued msg from ('::1', 64616, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750118073.22552:: Waiting for queued msg from ('::1', 64616, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971B16D0 [unset]>
# Created new WebSocketSender to ('::1', 64671, 0, 0)
# 1750118075.22661:: Client connected from: ('::1', 64671, 0, 0) : 4
# 1750118075.22661:: Waiting for queued msg from ('::1', 64671, 0, 0)
# 1750118075.22661:: Received msg from ('::1', 64671, 0, 0): {"35":"A","49":-1}
# 1750118075.22661:: Dequeued msg from ('::1', 64503, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750118075.22661:: Waiting for queued msg from ('::1', 64503, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971B1D60 [unset]>
# 1750118655.57192:: recv failed for ('::1', 64671, 0, 0)
# 1750118655.57192:: Done waiting on ('::1', 64671, 0, 0)
# Client connection closed: ('::1', 64671, 0, 0)
# 1750118655.573933:: Dequeued msg from ('::1', 64668, 0, 0): None
# 1750118655.573933:: Done waiting to dequeue msg from ('::1', 64668, 0, 0)
# 1750118655.575948:: recv failed for ('::1', 64668, 0, 0)
# 1750118655.575948:: Done waiting on ('::1', 64668, 0, 0)
# Client connection closed: ('::1', 64668, 0, 0)
# 1750118655.575948:: Dequeued msg from ('::1', 64616, 0, 0): None
# 1750118655.577711:: Done waiting to dequeue msg from ('::1', 64616, 0, 0)
# 1750118655.577711:: recv failed for ('::1', 64616, 0, 0)
# 1750118655.577711:: Done waiting on ('::1', 64616, 0, 0)
# Client connection closed: ('::1', 64616, 0, 0)
# 1750118655.577711:: recv failed for ('::1', 64503, 0, 0)
# 1750118655.577711:: Done waiting on ('::1', 64503, 0, 0)
# Client connection closed: ('::1', 64503, 0, 0)
# 1750118655.577711:: Dequeued msg from ('::1', 64671, 0, 0): None
# 1750118655.577711:: Done waiting to dequeue msg from ('::1', 64671, 0, 0)
# 1750118655.577711:: Dequeued msg from ('::1', 64503, 0, 0): None
# 1750118655.577711:: Done waiting to dequeue msg from ('::1', 64503, 0, 0)
# Created new WebSocketSender to ('::1', 49191, 0, 0)
# 1750119422.265981:: Client connected from: ('::1', 49191, 0, 0) : 1
# 1750119422.265981:: Waiting for queued msg from ('::1', 49191, 0, 0)
# 1750119422.26826:: Received msg from ('::1', 49191, 0, 0): {"35":"A","49":-1}
# 1750119422.26826:: Dequeued msg from ('::1', 49191, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119422.269256:: Waiting for queued msg from ('::1', 49191, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971B15B0 [unset]>
# 1750119444.607759:: recv failed for ('::1', 49191, 0, 0)
# 1750119444.607759:: Done waiting on ('::1', 49191, 0, 0)
# 1750119444.607759:: Dequeued msg from ('::1', 49191, 0, 0): None
# 1750119444.607759:: Done waiting to dequeue msg from ('::1', 49191, 0, 0)
# Client connection closed: ('::1', 49191, 0, 0)
# Created new WebSocketSender to ('::1', 49227, 0, 0)
# 1750119445.108592:: Client connected from: ('::1', 49227, 0, 0) : 1
# 1750119445.109593:: Waiting for queued msg from ('::1', 49227, 0, 0)
# 1750119445.136304:: Received msg from ('::1', 49227, 0, 0): {"35":"A","49":-1}
# 1750119445.136304:: Dequeued msg from ('::1', 49227, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119445.137305:: Waiting for queued msg from ('::1', 49227, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971C6040 [unset]>
# Created new WebSocketSender to ('::1', 49272, 0, 0)
# 1750119492.232848:: Client connected from: ('::1', 49272, 0, 0) : 2
# 1750119492.232848:: Waiting for queued msg from ('::1', 49272, 0, 0)
# 1750119492.232848:: Received msg from ('::1', 49272, 0, 0): {"35":"A","49":-1}
# 1750119492.23486:: Dequeued msg from ('::1', 49227, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119492.23486:: Waiting for queued msg from ('::1', 49227, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971C6700 [unset]>
# 1750119505.282547:: recv failed for ('::1', 49227, 0, 0)
# 1750119505.282547:: Done waiting on ('::1', 49227, 0, 0)
# 1750119505.282547:: Dequeued msg from ('::1', 49272, 0, 0): None
# 1750119505.292024:: Done waiting to dequeue msg from ('::1', 49272, 0, 0)
# 1750119505.292024:: recv failed for ('::1', 49272, 0, 0)
# 1750119505.292024:: Done waiting on ('::1', 49272, 0, 0)
# Client connection closed: ('::1', 49227, 0, 0)
# 1750119505.292024:: Dequeued msg from ('::1', 49227, 0, 0): None
# 1750119505.29304:: Done waiting to dequeue msg from ('::1', 49227, 0, 0)
# Client connection closed: ('::1', 49272, 0, 0)
# Created new WebSocketSender to ('::1', 49284, 0, 0)
# 1750119505.730524:: Client connected from: ('::1', 49284, 0, 0) : 1
# 1750119505.731518:: Waiting for queued msg from ('::1', 49284, 0, 0)
# 1750119505.73752:: Received msg from ('::1', 49284, 0, 0): {"35":"A","49":-1}
# 1750119505.738519:: Dequeued msg from ('::1', 49284, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119505.738519:: Waiting for queued msg from ('::1', 49284, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971C6550 [unset]>
# Created new WebSocketSender to ('::1', 49350, 0, 0)
# 1750119600.231848:: Client connected from: ('::1', 49350, 0, 0) : 2
# 1750119600.231848:: Waiting for queued msg from ('::1', 49350, 0, 0)
# 1750119600.267471:: Received msg from ('::1', 49350, 0, 0): {"35":"A","49":-1}
# 1750119600.267471:: Dequeued msg from ('::1', 49284, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119600.267471:: Waiting for queued msg from ('::1', 49284, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971C6E20 [unset]>
# Created new WebSocketSender to ('::1', 49670, 0, 0)
# 1750119698.221429:: Client connected from: ('::1', 49670, 0, 0) : 3
# 1750119698.221429:: Waiting for queued msg from ('::1', 49670, 0, 0)
# 1750119698.221429:: Received msg from ('::1', 49670, 0, 0): {"35":"A","49":-1}
# 1750119698.221429:: Dequeued msg from ('::1', 49350, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119698.230235:: Waiting for queued msg from ('::1', 49350, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971D5460 [unset]>
# Created new WebSocketSender to ('::1', 49674, 0, 0)
# 1750119703.229757:: Client connected from: ('::1', 49674, 0, 0) : 4
# 1750119703.229757:: Waiting for queued msg from ('::1', 49674, 0, 0)
# 1750119703.231758:: Received msg from ('::1', 49674, 0, 0): {"35":"A","49":-1}
# 1750119703.231758:: Dequeued msg from ('::1', 49284, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119703.232758:: Waiting for queued msg from ('::1', 49284, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971D5B20 [unset]>
# Created new WebSocketSender to ('::1', 49676, 0, 0)
# 1750119706.223629:: Client connected from: ('::1', 49676, 0, 0) : 5
# 1750119706.225638:: Waiting for queued msg from ('::1', 49676, 0, 0)
# 1750119706.225638:: Received msg from ('::1', 49676, 0, 0): {"35":"A","49":-1}
# 1750119706.225638:: Dequeued msg from ('::1', 49670, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119706.227649:: Waiting for queued msg from ('::1', 49670, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971E52B0 [unset]>
# 1750119710.921377:: recv failed for ('::1', 49284, 0, 0)
# 1750119710.921377:: Done waiting on ('::1', 49284, 0, 0)
# 1750119710.923547:: Dequeued msg from ('::1', 49350, 0, 0): None
# 1750119710.923547:: Done waiting to dequeue msg from ('::1', 49350, 0, 0)
# 1750119710.923547:: recv failed for ('::1', 49350, 0, 0)
# 1750119710.923547:: Done waiting on ('::1', 49350, 0, 0)
# 1750119710.923547:: Dequeued msg from ('::1', 49674, 0, 0): None
# 1750119710.923547:: Done waiting to dequeue msg from ('::1', 49674, 0, 0)
# 1750119710.923547:: recv failed for ('::1', 49670, 0, 0)
# 1750119710.923547:: Done waiting on ('::1', 49670, 0, 0)
# Client connection closed: ('::1', 49284, 0, 0)
# 1750119710.923547:: Dequeued msg from ('::1', 49284, 0, 0): None
# 1750119710.923547:: Done waiting to dequeue msg from ('::1', 49284, 0, 0)
# 1750119710.923547:: recv failed for ('::1', 49674, 0, 0)
# 1750119710.923547:: Done waiting on ('::1', 49674, 0, 0)
# 1750119710.923547:: recv failed for ('::1', 49676, 0, 0)
# 1750119710.923547:: Done waiting on ('::1', 49676, 0, 0)
# Client connection closed: ('::1', 49350, 0, 0)
# 1750119710.923547:: Dequeued msg from ('::1', 49676, 0, 0): None
# 1750119710.923547:: Done waiting to dequeue msg from ('::1', 49676, 0, 0)
# 1750119710.923547:: Dequeued msg from ('::1', 49670, 0, 0): None
# 1750119710.923547:: Done waiting to dequeue msg from ('::1', 49670, 0, 0)
# Client connection closed: ('::1', 49670, 0, 0)
# Client connection closed: ('::1', 49676, 0, 0)
# Client connection closed: ('::1', 49674, 0, 0)
# Created new WebSocketSender to ('::1', 49682, 0, 0)
# 1750119711.444477:: Client connected from: ('::1', 49682, 0, 0) : 1
# 1750119711.444477:: Waiting for queued msg from ('::1', 49682, 0, 0)
# 1750119711.450697:: Received msg from ('::1', 49682, 0, 0): {"35":"A","49":-1}
# 1750119711.450697:: Dequeued msg from ('::1', 49682, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119711.451711:: Waiting for queued msg from ('::1', 49682, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971C60A0 [unset]>
# Created new WebSocketSender to ('::1', 49894, 0, 0)
# 1750119785.223581:: Client connected from: ('::1', 49894, 0, 0) : 2
# 1750119785.223581:: Waiting for queued msg from ('::1', 49894, 0, 0)
# 1750119785.223581:: Received msg from ('::1', 49894, 0, 0): {"35":"A","49":-1}
# 1750119785.223581:: Dequeued msg from ('::1', 49682, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750119785.223581:: Waiting for queued msg from ('::1', 49682, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971E5250 [unset]>
# Created new WebSocketSender to ('::1', 50146, 0, 0)
# 1750120092.228541:: Client connected from: ('::1', 50146, 0, 0) : 3
# 1750120092.228541:: Waiting for queued msg from ('::1', 50146, 0, 0)
# 1750120092.230554:: Received msg from ('::1', 50146, 0, 0): {"35":"A","49":-1}
# 1750120092.230554:: Dequeued msg from ('::1', 49894, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120092.230554:: Waiting for queued msg from ('::1', 49894, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971E5970 [unset]>
# Created new WebSocketSender to ('::1', 50153, 0, 0)
# 1750120093.221424:: Client connected from: ('::1', 50153, 0, 0) : 4
# 1750120093.221424:: Waiting for queued msg from ('::1', 50153, 0, 0)
# 1750120093.221424:: Received msg from ('::1', 50153, 0, 0): {"35":"A","49":-1}
# 1750120093.221424:: Dequeued msg from ('::1', 49682, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120093.221424:: Waiting for queued msg from ('::1', 49682, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971E5F10 [unset]>
# Created new WebSocketSender to ('::1', 50193, 0, 0)
# 1750120156.221186:: Client connected from: ('::1', 50193, 0, 0) : 5
# 1750120156.221186:: Waiting for queued msg from ('::1', 50193, 0, 0)
# 1750120156.221186:: Received msg from ('::1', 50193, 0, 0): {"35":"A","49":-1}
# 1750120156.221186:: Dequeued msg from ('::1', 50146, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120156.221186:: Waiting for queued msg from ('::1', 50146, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971F6670 [unset]>
# 1750120167.867237:: recv failed for ('::1', 49682, 0, 0)
# 1750120167.867237:: Done waiting on ('::1', 49682, 0, 0)
# 1750120167.867237:: Dequeued msg from ('::1', 49894, 0, 0): None
# 1750120167.867237:: Done waiting to dequeue msg from ('::1', 49894, 0, 0)
# 1750120167.867237:: recv failed for ('::1', 49894, 0, 0)
# 1750120167.867237:: Done waiting on ('::1', 49894, 0, 0)
# Client connection closed: ('::1', 49682, 0, 0)
# 1750120167.867237:: Dequeued msg from ('::1', 50153, 0, 0): None
# 1750120167.867237:: Done waiting to dequeue msg from ('::1', 50153, 0, 0)
# 1750120167.867237:: recv failed for ('::1', 50146, 0, 0)
# 1750120167.867237:: Done waiting on ('::1', 50146, 0, 0)
# 1750120167.867237:: Dequeued msg from ('::1', 49682, 0, 0): None
# 1750120167.867237:: Done waiting to dequeue msg from ('::1', 49682, 0, 0)
# 1750120167.867237:: recv failed for ('::1', 50153, 0, 0)
# 1750120167.867237:: Done waiting on ('::1', 50153, 0, 0)
# 1750120167.867237:: recv failed for ('::1', 50193, 0, 0)
# 1750120167.867237:: Done waiting on ('::1', 50193, 0, 0)
# Client connection closed: ('::1', 49894, 0, 0)
# 1750120167.867237:: Dequeued msg from ('::1', 50193, 0, 0): None
# 1750120167.867237:: Done waiting to dequeue msg from ('::1', 50193, 0, 0)
# 1750120167.867237:: Dequeued msg from ('::1', 50146, 0, 0): None
# 1750120167.867237:: Done waiting to dequeue msg from ('::1', 50146, 0, 0)
# Client connection closed: ('::1', 50146, 0, 0)
# Client connection closed: ('::1', 50153, 0, 0)
# Client connection closed: ('::1', 50193, 0, 0)
# Created new WebSocketSender to ('::1', 50206, 0, 0)
# 1750120168.236129:: Client connected from: ('::1', 50206, 0, 0) : 1
# 1750120168.236129:: Waiting for queued msg from ('::1', 50206, 0, 0)
# 1750120168.240131:: Received msg from ('::1', 50206, 0, 0): {"35":"A","49":-1}
# 1750120168.240131:: Dequeued msg from ('::1', 50206, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120168.241132:: Waiting for queued msg from ('::1', 50206, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971E58B0 [unset]>
# 1750120183.954603:: recv failed for ('::1', 50206, 0, 0)
# 1750120183.955603:: Done waiting on ('::1', 50206, 0, 0)
# 1750120183.955603:: Dequeued msg from ('::1', 50206, 0, 0): None
# 1750120183.955603:: Done waiting to dequeue msg from ('::1', 50206, 0, 0)
# Client connection closed: ('::1', 50206, 0, 0)
# Created new WebSocketSender to ('::1', 50226, 0, 0)
# 1750120184.286692:: Client connected from: ('::1', 50226, 0, 0) : 1
# 1750120184.287698:: Waiting for queued msg from ('::1', 50226, 0, 0)
# 1750120184.298812:: Received msg from ('::1', 50226, 0, 0): {"35":"A","49":-1}
# 1750120184.298812:: Dequeued msg from ('::1', 50226, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120184.299811:: Waiting for queued msg from ('::1', 50226, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971E5820 [unset]>
# Created new WebSocketSender to ('::1', 50235, 0, 0)
# 1750120195.229752:: Client connected from: ('::1', 50235, 0, 0) : 2
# 1750120195.229752:: Waiting for queued msg from ('::1', 50235, 0, 0)
# 1750120195.232742:: Received msg from ('::1', 50235, 0, 0): {"35":"A","49":-1}
# 1750120195.233745:: Dequeued msg from ('::1', 50226, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120195.233745:: Waiting for queued msg from ('::1', 50226, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971F69A0 [unset]>
# 1750120199.206736:: recv failed for ('::1', 50226, 0, 0)
# 1750120199.207749:: Done waiting on ('::1', 50226, 0, 0)
# 1750120199.208752:: Dequeued msg from ('::1', 50235, 0, 0): None
# 1750120199.208752:: Done waiting to dequeue msg from ('::1', 50235, 0, 0)
# 1750120199.208752:: recv failed for ('::1', 50235, 0, 0)
# 1750120199.208752:: Done waiting on ('::1', 50235, 0, 0)
# Client connection closed: ('::1', 50226, 0, 0)
# 1750120199.209752:: Dequeued msg from ('::1', 50226, 0, 0): None
# 1750120199.209752:: Done waiting to dequeue msg from ('::1', 50226, 0, 0)
# Client connection closed: ('::1', 50235, 0, 0)
# Created new WebSocketSender to ('::1', 50242, 0, 0)
# 1750120199.619082:: Client connected from: ('::1', 50242, 0, 0) : 1
# 1750120199.620081:: Waiting for queued msg from ('::1', 50242, 0, 0)
# 1750120199.627085:: Received msg from ('::1', 50242, 0, 0): {"35":"A","49":-1}
# 1750120199.627085:: Dequeued msg from ('::1', 50242, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120199.628088:: Waiting for queued msg from ('::1', 50242, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB971F6A90 [unset]>
# Created new WebSocketSender to ('::1', 50323, 0, 0)
# 1750120327.225341:: Client connected from: ('::1', 50323, 0, 0) : 2
# 1750120327.225341:: Waiting for queued msg from ('::1', 50323, 0, 0)
# 1750120327.235735:: Received msg from ('::1', 50323, 0, 0): {"35":"A","49":-1}
# 1750120327.235735:: Dequeued msg from ('::1', 50242, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120327.235735:: Waiting for queued msg from ('::1', 50242, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9720C1F0 [unset]>
# Created new WebSocketSender to ('::1', 50333, 0, 0)
# 1750120334.224867:: Client connected from: ('::1', 50333, 0, 0) : 3
# 1750120334.224867:: Waiting for queued msg from ('::1', 50333, 0, 0)
# 1750120334.225867:: Received msg from ('::1', 50333, 0, 0): {"35":"A","49":-1}
# 1750120334.225867:: Dequeued msg from ('::1', 50323, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120334.226864:: Waiting for queued msg from ('::1', 50323, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9720C700 [unset]>
# Created new WebSocketSender to ('::1', 50337, 0, 0)
# 1750120336.340493:: Client connected from: ('::1', 50337, 0, 0) : 4
# 1750120336.340493:: Waiting for queued msg from ('::1', 50337, 0, 0)
# 1750120336.344886:: Received msg from ('::1', 50337, 0, 0): {"35":"A","49":-1}
# 1750120336.344886:: Dequeued msg from ('::1', 50242, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120336.346927:: Waiting for queued msg from ('::1', 50242, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9720CCD0 [unset]>
# 1750120338.707405:: recv failed for ('::1', 50242, 0, 0)
# 1750120338.709427:: Done waiting on ('::1', 50242, 0, 0)
# 1750120338.709427:: Dequeued msg from ('::1', 50333, 0, 0): None
# 1750120338.709427:: Done waiting to dequeue msg from ('::1', 50333, 0, 0)
# 1750120338.712237:: recv failed for ('::1', 50323, 0, 0)
# 1750120338.712237:: Done waiting on ('::1', 50323, 0, 0)
# 1750120338.712237:: recv failed for ('::1', 50333, 0, 0)
# 1750120338.712237:: Done waiting on ('::1', 50333, 0, 0)
# Client connection closed: ('::1', 50242, 0, 0)
# 1750120338.714262:: Dequeued msg from ('::1', 50323, 0, 0): None
# 1750120338.714262:: Done waiting to dequeue msg from ('::1', 50323, 0, 0)
# 1750120338.714262:: Dequeued msg from ('::1', 50337, 0, 0): None
# 1750120338.714262:: Done waiting to dequeue msg from ('::1', 50337, 0, 0)
# 1750120338.714262:: recv failed for ('::1', 50337, 0, 0)
# 1750120338.714262:: Done waiting on ('::1', 50337, 0, 0)
# 1750120338.714262:: Dequeued msg from ('::1', 50242, 0, 0): None
# 1750120338.714262:: Done waiting to dequeue msg from ('::1', 50242, 0, 0)
# Client connection closed: ('::1', 50323, 0, 0)
# Client connection closed: ('::1', 50333, 0, 0)
# Client connection closed: ('::1', 50337, 0, 0)
# Created new WebSocketSender to ('::1', 50342, 0, 0)
# 1750120339.076145:: Client connected from: ('::1', 50342, 0, 0) : 1
# 1750120339.077319:: Waiting for queued msg from ('::1', 50342, 0, 0)
# 1750120339.079321:: Received msg from ('::1', 50342, 0, 0): {"35":"A","49":-1}
# 1750120339.079321:: Dequeued msg from ('::1', 50342, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120339.080324:: Waiting for queued msg from ('::1', 50342, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9720CC10 [unset]>
# Created new WebSocketSender to ('::1', 50396, 0, 0)
# 1750120417.233626:: Client connected from: ('::1', 50396, 0, 0) : 2
# 1750120417.233626:: Waiting for queued msg from ('::1', 50396, 0, 0)
# 1750120417.235637:: Received msg from ('::1', 50396, 0, 0): {"35":"A","49":-1}
# 1750120417.235637:: Dequeued msg from ('::1', 50342, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120417.235637:: Waiting for queued msg from ('::1', 50342, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9721D040 [unset]>
# Created new WebSocketSender to ('::1', 50409, 0, 0)
# 1750120425.225465:: Client connected from: ('::1', 50409, 0, 0) : 3
# 1750120425.225465:: Waiting for queued msg from ('::1', 50409, 0, 0)
# 1750120425.225465:: Received msg from ('::1', 50409, 0, 0): {"35":"A","49":-1}
# 1750120425.225465:: Dequeued msg from ('::1', 50396, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120425.225465:: Waiting for queued msg from ('::1', 50396, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9721D610 [unset]>
# Created new WebSocketSender to ('::1', 50411, 0, 0)
# 1750120428.236115:: Client connected from: ('::1', 50411, 0, 0) : 4
# 1750120428.236115:: Waiting for queued msg from ('::1', 50411, 0, 0)
# 1750120428.236115:: Received msg from ('::1', 50411, 0, 0): {"35":"A","49":-1}
# 1750120428.236115:: Dequeued msg from ('::1', 50342, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750120428.236115:: Waiting for queued msg from ('::1', 50342, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB9721DC10 [unset]>
# Created new WebSocketSender to ('::1', 50415, 0, 0)
# 1750120434.22427:: Client connected from: ('::1', 50415, 0, 0) : 5
# 1750120434.22427:: Waiting for queued msg from ('::1', 50415, 0, 0)
# 1750120434.225274:: Received msg from ('::1', 50415, 0, 0): {"35":"A","49":-1}
# ...
# 1750124487.221102:: Client connected from: ('::1', 53380, 0, 0) : 4
# 1750124487.221102:: Waiting for queued msg from ('::1', 53380, 0, 0)
# 1750124487.252844:: Received msg from ('::1', 53380, 0, 0): {"35":"A","49":-1}
# 1750124487.252844:: Dequeued msg from ('::1', 53262, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750124487.252844:: Waiting for queued msg from ('::1', 53262, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB973C5B50 [unset]>
# Created new WebSocketSender to ('::1', 53390, 0, 0)
# 1750124503.220911:: Client connected from: ('::1', 53390, 0, 0) : 5
# 1750124503.23151:: Waiting for queued msg from ('::1', 53390, 0, 0)
# 1750124503.232551:: Received msg from ('::1', 53390, 0, 0): {"35":"A","49":-1}
# 1750124503.232551:: Dequeued msg from ('::1', 53322, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750124503.232551:: Waiting for queued msg from ('::1', 53322, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB973C55E0 [unset]>
# Created new WebSocketSender to ('::1', 53425, 0, 0)
# 1750124542.235744:: Client connected from: ('::1', 53425, 0, 0) : 6
# 1750124542.235744:: Waiting for queued msg from ('::1', 53425, 0, 0)
# 1750124542.237948:: Received msg from ('::1', 53425, 0, 0): {"35":"A","49":-1}
# 1750124542.244272:: Dequeued msg from ('::1', 53321, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750124542.244272:: Waiting for queued msg from ('::1', 53321, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB973F3460 [unset]>
# Created new WebSocketSender to ('::1', 53431, 0, 0)
# 1750124548.217839:: Client connected from: ('::1', 53431, 0, 0) : 7
# 1750124548.217839:: Waiting for queued msg from ('::1', 53431, 0, 0)
# 1750124548.233773:: Received msg from ('::1', 53431, 0, 0): {"35":"A","49":-1}
# 1750124548.233773:: Dequeued msg from ('::1', 53380, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750124548.233773:: Waiting for queued msg from ('::1', 53380, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB973F3A00 [unset]>
# 1750124551.184017:: recv failed for ('::1', 53262, 0, 0)
# 1750124551.191318:: Done waiting on ('::1', 53262, 0, 0)
# 1750124551.193261:: Dequeued msg from ('::1', 53262, 0, 0): None
# 1750124551.193261:: Done waiting to dequeue msg from ('::1', 53262, 0, 0)
# 1750124551.193657:: recv failed for ('::1', 53321, 0, 0)
# 1750124551.193657:: Done waiting on ('::1', 53321, 0, 0)
# 1750124551.193657:: recv failed for ('::1', 53322, 0, 0)
# 1750124551.193657:: Done waiting on ('::1', 53322, 0, 0)
# Client connection closed: ('::1', 53262, 0, 0)
# 1750124551.193657:: Dequeued msg from ('::1', 53390, 0, 0): None
# 1750124551.193657:: Done waiting to dequeue msg from ('::1', 53390, 0, 0)
# 1750124551.193657:: Dequeued msg from ('::1', 53322, 0, 0): None
# 1750124551.193657:: Done waiting to dequeue msg from ('::1', 53322, 0, 0)
# 1750124551.193657:: recv failed for ('::1', 53380, 0, 0)
# 1750124551.193657:: Done waiting on ('::1', 53380, 0, 0)
# 1750124551.193657:: Dequeued msg from ('::1', 53425, 0, 0): None
# 1750124551.193657:: Done waiting to dequeue msg from ('::1', 53425, 0, 0)
# 1750124551.193657:: recv failed for ('::1', 53390, 0, 0)
# 1750124551.193657:: Done waiting on ('::1', 53390, 0, 0)
# 1750124551.193657:: recv failed for ('::1', 53425, 0, 0)
# 1750124551.193657:: Done waiting on ('::1', 53425, 0, 0)
# 1750124551.193657:: recv failed for ('::1', 53431, 0, 0)
# 1750124551.193657:: Done waiting on ('::1', 53431, 0, 0)
# Client connection closed: ('::1', 53321, 0, 0)
# Client connection closed: ('::1', 53322, 0, 0)
# 1750124551.193657:: Dequeued msg from ('::1', 53321, 0, 0): None
# 1750124551.193657:: Done waiting to dequeue msg from ('::1', 53321, 0, 0)
# 1750124551.193657:: Dequeued msg from ('::1', 53431, 0, 0): None
# 1750124551.193657:: Done waiting to dequeue msg from ('::1', 53431, 0, 0)
# 1750124551.193657:: Dequeued msg from ('::1', 53380, 0, 0): None
# 1750124551.193657:: Done waiting to dequeue msg from ('::1', 53380, 0, 0)
# Client connection closed: ('::1', 53380, 0, 0)
# Client connection closed: ('::1', 53390, 0, 0)
# Client connection closed: ('::1', 53425, 0, 0)
# Client connection closed: ('::1', 53431, 0, 0)
# Created new WebSocketSender to ('::1', 53437, 0, 0)
# 1750124551.645184:: Client connected from: ('::1', 53437, 0, 0) : 1
# 1750124551.645184:: Waiting for queued msg from ('::1', 53437, 0, 0)
# 1750124551.728966:: Received msg from ('::1', 53437, 0, 0): {"35":"A","49":-1}
# 1750124551.728966:: Dequeued msg from ('::1', 53437, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750124551.728966:: Waiting for queued msg from ('::1', 53437, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB973416D0 [unset]>
# 1750124564.425119:: Received msg from ('::1', 53437, 0, 0): {"35":"D","38":10,"44":764.38,"49":153}
# 1750124564.426237:: Dequeued msg from ('::1', 53437, 0, 0): {"35":"D","38":10,"44":764.38,"49":153}
# 1750124564.426237:: Waiting for queued msg from ('::1', 53437, 0, 0)
# 1750124564.426237:: OB:Setting New Order AckEvent: <DataEvent.AsyncDataEvent object at 0x000001AB973416D0 [unset, waiters:1]>
# MS:New ack: OrderStatus.NEW -11 153 {1: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB86723490>, 2: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB8671D8E0>, 3: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB8671D4F0>, 4: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB8671D4F0>, 5: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB970AF610>, 6: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB970AFF40>, 7: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB970AFF40>, 8: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9714E490>, 9: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB970AFF40>, 10: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB866E59A0>, 11: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB866E59A0>, 12: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9714EE20>, 13: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9714ECD0>, 14: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9714ECD0>, 15: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9715BD60>, 16: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9715BD60>, 17: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9715B3A0>, 18: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9715B3A0>, 19: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9716FBE0>, 20: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9716F910>, 21: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9716F910>, 22: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9717D790>, 23: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9717D5E0>, 24: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9717D5E0>, 25: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9718B310>, 26: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9718B760>, 27: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9718B820>, 28: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9718B340>, 29: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E2E0>, 30: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E2E0>, 31: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719EAF0>, 32: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E2E0>, 33: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E8B0>, 34: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E8E0>, 35: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E8E0>, 36: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971B1E50>, 37: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971B1E50>, 38: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971C69A0>, 39: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971B1E50>, 40: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971C67C0>, 41: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971D5CA0>, 42: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971D5CA0>, 43: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971C6970>, 44: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971D5CA0>, 45: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971E5280>, 46: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971D5130>, 47: <websockets.legacy.server.WebSocketServerProtocol object a ...
# MS:Awaiting acks
# 1750124566.796917:: Received msg from ('::1', 53437, 0, 0): {"11":-11,"35":"F","49":153}
# 1750124566.800028:: Dequeued msg from ('::1', 53437, 0, 0): {"11":-11,"35":"F","49":153}
# 1750124566.800028:: Waiting for queued msg from ('::1', 53437, 0, 0)
# Cancel order -11
# MS:New ack: OrderStatus.CANCELLED -11 153 {1: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB86723490>, 2: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB8671D8E0>, 3: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB8671D4F0>, 4: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB8671D4F0>, 5: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB970AF610>, 6: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB970AFF40>, 7: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB970AFF40>, 8: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9714E490>, 9: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB970AFF40>, 10: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB866E59A0>, 11: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB866E59A0>, 12: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9714EE20>, 13: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9714ECD0>, 14: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9714ECD0>, 15: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9715BD60>, 16: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9715BD60>, 17: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9715B3A0>, 18: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9715B3A0>, 19: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9716FBE0>, 20: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9716F910>, 21: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9716F910>, 22: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9717D790>, 23: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9717D5E0>, 24: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9717D5E0>, 25: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9718B310>, 26: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9718B760>, 27: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9718B820>, 28: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9718B340>, 29: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E2E0>, 30: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E2E0>, 31: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719EAF0>, 32: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E2E0>, 33: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E8B0>, 34: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E8E0>, 35: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB9719E8E0>, 36: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971B1E50>, 37: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971B1E50>, 38: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971C69A0>, 39: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971B1E50>, 40: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971C67C0>, 41: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971D5CA0>, 42: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971D5CA0>, 43: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971C6970>, 44: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971D5CA0>, 45: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971E5280>, 46: <websockets.legacy.server.WebSocketServerProtocol object at 0x000001AB971D5130>, 47: <websockets.legacy.server.WebSocketServerProtocol ob ...
# MS:Awaiting acks
# Created new WebSocketSender to ('::1', 53470, 0, 0)
# 1750124592.229645:: Client connected from: ('::1', 53470, 0, 0) : 2
# 1750124592.229645:: Waiting for queued msg from ('::1', 53470, 0, 0)
# 1750124592.230826:: Received msg from ('::1', 53470, 0, 0): {"35":"A","49":-1}
# 1750124592.230826:: Dequeued msg from ('::1', 53437, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750124592.231832:: Waiting for queued msg from ('::1', 53437, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB973F3790 [unset]>
# Created new WebSocketSender to ('::1', 53480, 0, 0)
# 1750124604.230376:: Client connected from: ('::1', 53480, 0, 0) : 3
# 1750124604.230376:: Waiting for queued msg from ('::1', 53480, 0, 0)
# 1750124604.231381:: Received msg from ('::1', 53480, 0, 0): {"35":"A","49":-1}
# 1750124604.231381:: Dequeued msg from ('::1', 53470, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750124604.232376:: Waiting for queued msg from ('::1', 53470, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB973F3B20 [unset]>
# 1750124625.946511:: recv failed for ('::1', 53437, 0, 0)
# 1750124625.946511:: Done waiting on ('::1', 53437, 0, 0)
# 1750124625.946511:: Dequeued msg from ('::1', 53437, 0, 0): None
# 1750124625.947628:: Done waiting to dequeue msg from ('::1', 53437, 0, 0)
# 1750124625.947628:: recv failed for ('::1', 53470, 0, 0)
# 1750124625.947628:: Done waiting on ('::1', 53470, 0, 0)
# 1750124625.947628:: recv failed for ('::1', 53480, 0, 0)
# 1750124625.947628:: Done waiting on ('::1', 53480, 0, 0)
# Client connection closed: ('::1', 53437, 0, 0)
# 1750124625.947628:: Dequeued msg from ('::1', 53480, 0, 0): None
# 1750124625.947628:: Done waiting to dequeue msg from ('::1', 53480, 0, 0)
# 1750124625.947628:: Dequeued msg from ('::1', 53470, 0, 0): None
# 1750124625.947628:: Done waiting to dequeue msg from ('::1', 53470, 0, 0)
# Client connection closed: ('::1', 53470, 0, 0)
# Client connection closed: ('::1', 53480, 0, 0)
# Created new WebSocketSender to ('::1', 53507, 0, 0)
# 1750124626.384057:: Client connected from: ('::1', 53507, 0, 0) : 1
# 1750124626.384057:: Waiting for queued msg from ('::1', 53507, 0, 0)
# 1750124626.395056:: Received msg from ('::1', 53507, 0, 0): {"35":"A","49":-1}
# 1750124626.395056:: Dequeued msg from ('::1', 53507, 0, 0): {"35":"A","49":-1}
# Logon message
# New Client
# Created MM
# 1750124626.395056:: Waiting for queued msg from ('::1', 53507, 0, 0)
# MM Awaiting ack event set: <DataEvent.AsyncDataEvent object at 0x000001AB973F3400 [unset]>

# %%
#python -m nbconvert --to script MarketSimulator.ipynb
